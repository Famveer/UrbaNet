# %%
import numpy as np
import pandas as pd
import re
import sys, os
import glob
import gc
import itertools
import zipfile

from tqdm import tqdm
import shutil

from pathlib import Path

here_path = Path().resolve()
repo_path = here_path.parents[2]
sys.path.append(str(repo_path))

#module_path = os.path.abspath(os.path.join('../../'))
#if module_path not in sys.path:
#    sys.path.append(module_path)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from py.utils import verifyDir
from py.datasets.dataprocess.comparisons import AHPWeights

# %%
geo_level="All"

# %%
DATA_PATH = f"{repo_path}/data/pp2/"
CSV_PATH=f"{DATA_PATH}raw/"
PP_IMAGES_PATH=f"{DATA_PATH}images/"

PROCESSED_PATH=f"{DATA_PATH}processed/"
QSCORE_PATH=f"{PROCESSED_PATH}AHPScores/"
GEO_LEVEL_PATH=f"{QSCORE_PATH}{geo_level}/"
RESULTS_PATH=f"{GEO_LEVEL_PATH}Scores/"
IMAGES_PATH=f"{GEO_LEVEL_PATH}Images/"

N_JOBS=8

# %%
verifyDir(QSCORE_PATH)
verifyDir(RESULTS_PATH)
verifyDir(IMAGES_PATH)

# %%
# %%time
pp2_comparisons_df = pd.read_csv(zipfile.ZipFile(f"{PROCESSED_PATH}HumanEvaluations.zip").open("HumanEvaluations/comparisons.csv"), sep=";", low_memory=False)
pp2_comparisons_df
# Out:
# CPU times: user 7.96 s, sys: 553 ms, total: 8.52 s
# Wall time: 8.51 s
#                           vote_id                   left_id  \
# 0        5815426b02a8dc05afdf2b74  50e5f7d4d7c3df413b00056a
# 1        51f2e453ad93a763cc1d2e9c  50e5f7d4d7c3df413b00056a
# 2        546fd72802a8dc4bc0758a3b  50e5f7d4d7c3df413b00056a
# 3        537e474402a8dc0677005191  50e5f7d4d7c3df413b00056a
# 4        523376dead93a760f8daa56b  50e5f7d4d7c3df413b00056a
# ...                           ...                       ...
# 1555543  51f80ed7ad93a780c8788fc6  5185cd21fdc9f03fd5000cdf
# 1555544  592c770302a8dc05afdfa4f3  5185cd21fdc9f03fd5000cdf
# 1555545  543e49d002a8dc4bbe75863a  5185cd21fdc9f03fd5000cdf
# 1555546  586ba57302a8dc05afdf5c3b  5185cd21fdc9f03fd5000cdf
# 1555547  53ae2eb202a8dc6a60287036  5185cd21fdc9f03fd5000cdf
#
#                          right_id winner   category  \
# 0        50f42c0dfdc9f065f00017bc   left     safety
# 1        50f562ddfdc9f065f0005af3  right     safety
# 2        50f5eb24fdc9f065f000804a  right     safety
# 3        50f5eb4afdc9f065f00081bb  equal  beautiful
# 4        513cbda1fdc9f035870010d9   left     safety
# ...                           ...    ...        ...
# 1555543  513e6465fdc9f0358700b812   left    wealthy
# 1555544  513e6c96fdc9f0358700c1ac   left     safety
# 1555545  51408cabfdc9f0358700eb8a  right     lively
# 1555546  51409d77fdc9f049260012ff   left     safety
# 1555547  5140d8c0fdc9f04926003a9a  right     safety
#
#                            voter_uniqueid   left_lat   left_long  left_city  \
# 0        8f5fe1b8602349f7bdf8a27e5ae75a48  22.310524  114.170637  Hong Kong
# 1        3a666b3c1ca84ccfa0cdd3c7423228f2  22.310524  114.170637  Hong Kong
# 2        b544eec9acb74a2f8a7f464560fe6242  22.310524  114.170637  Hong Kong
# 3        2035397a7a80404ab026246c9e42d991  22.310524  114.170637  Hong Kong
# 4        42e405acdb5f439a94f37df2121f0b1a  22.310524  114.170637  Hong Kong
# ...                                   ...        ...         ...        ...
# 1555543  eb9cb07d831a4888898ee8eb8649b52f  45.479466  -73.662663   Montreal
# 1555544  479c83d12ecd4c2db4cc46c56bc353b3  45.479466  -73.662663   Montreal
# 1555545  cf6fd73f3bab40c597ad5d57f24ea025  45.479466  -73.662663   Montreal
# 1555546  8459e27a9f104cf19d84a3d1bb9d8971  45.479466  -73.662663   Montreal
# 1555547  a56f27944ae64d6791cabc19d028d168  45.479466  -73.662663   Montreal
#
#         left_country left_continent                         left_image_path  \
# 0              China           Asia  Hong Kong/50e5f7d4d7c3df413b00056a.JPG
# 1              China           Asia  Hong Kong/50e5f7d4d7c3df413b00056a.JPG
# 2              China           Asia  Hong Kong/50e5f7d4d7c3df413b00056a.JPG
# 3              China           Asia  Hong Kong/50e5f7d4d7c3df413b00056a.JPG
# 4              China           Asia  Hong Kong/50e5f7d4d7c3df413b00056a.JPG
# ...              ...            ...                                     ...
# 1555543       Canada  North America   Montreal/5185d53bfdc9f03fd5001493.JPG
# 1555544       Canada  North America   Montreal/5185d53bfdc9f03fd5001493.JPG
# 1555545       Canada  North America   Montreal/5185d53bfdc9f03fd5001493.JPG
# 1555546       Canada  North America   Montreal/5185d53bfdc9f03fd5001493.JPG
# 1555547       Canada  North America   Montreal/5185d53bfdc9f03fd5001493.JPG
#
#          right_lat  right_long      right_city right_country right_continent  \
# 0        52.302266   20.989567          Warsaw        Poland          Europe
# 1         1.285515  103.810072       Singapore     Singapore            Asia
# 2       -22.807149  -43.413760  Rio De Janeiro        Brasil   South America
# 3       -22.805310  -43.427501  Rio De Janeiro        Brasil   South America
# 4        29.838246  -95.312139         Houston           USA   North America
# ...            ...         ...             ...           ...             ...
# 1555543  35.058854  135.756810           Kyoto         Japan            Asia
# 1555544  35.594405  139.765548           Tokyo         Japan            Asia
# 1555545  38.760147   -9.105329          Lisbon      Portugal          Europe
# 1555546  41.913943   12.425267            Rome         Italy          Europe
# 1555547  53.320232   -6.286370          Dublin       Ireland          Europe
#
#                                     right_image_path  \
# 0                Warsaw/50f42c0dfdc9f065f00017bc.JPG
# 1             Singapore/50f562ddfdc9f065f0005af3.JPG
# 2        Rio De Janeiro/50f5eb24fdc9f065f000804a.JPG
# 3        Rio De Janeiro/50f5eb4afdc9f065f00081bb.JPG
# 4               Houston/513cbda1fdc9f035870010d9.JPG
# ...                                              ...
# 1555543           Kyoto/513e6465fdc9f0358700b812.JPG
# 1555544           Tokyo/513e6c96fdc9f0358700c1ac.JPG
# 1555545          Lisbon/51408cabfdc9f0358700eb8a.JPG
# 1555546            Rome/51409d77fdc9f049260012ff.JPG
# 1555547          Dublin/5140d8c0fdc9f04926003a9a.JPG
#
#                                                sorted_pair     user_id
# 0        ('50e5f7d4d7c3df413b00056a', '50f42c0dfdc9f065...      user_0
# 1        ('50e5f7d4d7c3df413b00056a', '50f562ddfdc9f065...      user_1
# 2        ('50e5f7d4d7c3df413b00056a', '50f5eb24fdc9f065...      user_2
# 3        ('50e5f7d4d7c3df413b00056a', '50f5eb4afdc9f065...      user_3
# 4        ('50e5f7d4d7c3df413b00056a', '513cbda1fdc9f035...      user_4
# ...                                                    ...         ...
# 1555543  ('513e6465fdc9f0358700b812', '5185cd21fdc9f03f...   user_3390
# 1555544  ('513e6c96fdc9f0358700c1ac', '5185cd21fdc9f03f...  user_94573
# 1555545  ('51408cabfdc9f0358700eb8a', '5185cd21fdc9f03f...   user_4313
# 1555546  ('51409d77fdc9f049260012ff', '5185cd21fdc9f03f...  user_28625
# 1555547  ('5140d8c0fdc9f04926003a9a', '5185cd21fdc9f03f...  user_23634
#
# [1555548 rows x 20 columns]

# %% [markdown]
# ### Initialize AHP-Comparisons calculator

# %%
pp = AHPWeights(pp2_comparisons_df, place_level=geo_level)

# %%
metrics = pp.get_metrics()
metrics
# Out:
# array(['safety', 'beautiful', 'wealthy', 'lively', 'boring', 'depressing'],
#       dtype=object)

# %% [markdown]
# #### Calculating Elo-Rating per image

# %%
# %%time
images_metric = {"metrics":[], "values":[]}
summary_df = pd.DataFrame()
for metric in metrics:
    verifyDir(f"{RESULTS_PATH}{metric}/")
    
    # if Path(f"{RESULTS_PATH}{metric}/weights.csv").exists():
    #     weights_df = pd.read_csv(f"{RESULTS_PATH}{metric}/weights.csv", sep=";", low_memory=False)
    # else:
    pp.calculate_ahp_weights(metric=metric, method="dict")
    pp.normalize_ahp_weights()
    weights_df = pp.get_ahp_weights()
    weights_df.to_csv(f"{RESULTS_PATH}{metric}/weights.csv", sep=";", index=False)
    print(f"Saving {metric} in {RESULTS_PATH}{metric}/weights.csv")
    
    images_metric["metrics"].append(metric)
    images_metric["values"].append(weights_df.shape[0])
    
    if len(summary_df)==0:
        summary_df = weights_df[["image_id", "lat", "long", "city", "country", "continent", "AHPweight", "AHPScore"]].copy()
    else:
        summ_ = weights_df[["image_id", "lat", "long", "city", "country", "continent", "AHPweight", "AHPScore"]].copy()
        summary_df = pd.merge(summary_df, summ_, how="outer", on=["image_id", "lat", "long", "city", "country", "continent"])
    summary_df.rename(columns={"AHPweight": f"{metric}_AHPweight", "AHPScore": f"{metric}"}, inplace=True)
    
summary_df.fillna(0., inplace=True)
# Out:
# Analyzing 506164 safety comparisons
# Saving safety in /media/felipe/DATA19/github/FGV/PlacePulse/data/pp2/processed/AHPScores/All/Scores/safety/weights.csv
# Analyzing 219103 beautiful comparisons
# Saving beautiful in /media/felipe/DATA19/github/FGV/PlacePulse/data/pp2/processed/AHPScores/All/Scores/beautiful/weights.csv
# Analyzing 174088 wealthy comparisons
# Saving wealthy in /media/felipe/DATA19/github/FGV/PlacePulse/data/pp2/processed/AHPScores/All/Scores/wealthy/weights.csv
# Analyzing 363681 lively comparisons
# Saving lively in /media/felipe/DATA19/github/FGV/PlacePulse/data/pp2/processed/AHPScores/All/Scores/lively/weights.csv
# Analyzing 143610 boring comparisons
# Saving boring in /media/felipe/DATA19/github/FGV/PlacePulse/data/pp2/processed/AHPScores/All/Scores/boring/weights.csv
# Analyzing 148902 depressing comparisons
# Saving depressing in /media/felipe/DATA19/github/FGV/PlacePulse/data/pp2/processed/AHPScores/All/Scores/depressing/weights.csv
# CPU times: user 37.7 s, sys: 408 ms, total: 38.1 s
# Wall time: 38.3 s

# %% [markdown]
# #### Adding image paths

# %%
base_path = Path(PP_IMAGES_PATH)
img_path_list = np.sort([str(p.relative_to(base_path)) for p in base_path.glob('*/*.JPG')])
image_path_dict = {path.split("/")[-1].replace(".JPG",""): path for path in img_path_list}

# %%
# %%time
summary_df["image_path"] = summary_df["image_id"].map(image_path_dict)
summary_df = summary_df[~summary_df["image_path"].isna()].copy()
summary_df
# Out:
# CPU times: user 40.5 ms, sys: 1.03 ms, total: 41.5 ms
# Wall time: 40.5 ms
#                         image_id        lat        long       city country  \
# 0       50e5f7d4d7c3df413b00056a  22.310524  114.170637  Hong Kong   China
# 1       50e5f7d4d7c3df413b00056b  22.274799  114.192828  Hong Kong   China
# 2       50e5f7d4d7c3df413b00056c  22.291117  114.147373  Hong Kong   China
# 3       50e5f7d4d7c3df413b00056d  22.314273  114.177176  Hong Kong   China
# 4       50e5f7d4d7c3df413b00056e  22.332412  114.204790  Hong Kong   China
# ...                          ...        ...         ...        ...     ...
# 108815  5185d533fdc9f03fd500148d  45.635489  -73.514755   Montreal  Canada
# 108816  5185d533fdc9f03fd500148e  45.581265  -73.511511   Montreal  Canada
# 108817  5185d534fdc9f03fd500148f  45.591299  -73.520681   Montreal  Canada
# 108818  5185d534fdc9f03fd5001490  45.470656  -73.631901   Montreal  Canada
# 108819  5185d536fdc9f03fd5001491  45.626787  -73.547511   Montreal  Canada
#
#             continent  safety_AHPweight    safety  beautiful_AHPweight  \
# 0                Asia          0.184524  1.845238         9.999990e-07
# 1                Asia          0.353977  3.539772         1.000000e+00
# 2                Asia          0.116477  1.164773         4.999998e-07
# 3                Asia          0.384848  3.848476         9.999990e-07
# 4                Asia          0.250000  2.500000         9.239924e-06
# ...               ...               ...       ...                  ...
# 108815  North America          0.050000  0.500001         3.333333e-01
# 108816  North America          0.192308  1.923076         2.666666e-01
# 108817  North America          0.195466  1.954657         5.000000e-01
# 108818  North America          0.133929  1.339286         3.333330e-07
# 108819  North America          0.077922  0.779221         4.999995e-01
#
#         beautiful  wealthy_AHPweight    wealthy  lively_AHPweight    lively  \
# 0        0.000009           0.000009   0.000095      1.203704e-01  1.203704
# 1       10.000000           0.500000   5.000002      5.000000e-01  5.000000
# 2        0.000004           1.000000  10.000000      4.761903e-01  4.761903
# 3        0.000009           0.444444   4.444442      1.428571e-07  0.000001
# 4        0.000092           0.370370   3.703704      1.366668e-01  1.366668
# ...           ...                ...        ...               ...       ...
# 108815   3.333333           0.000009   0.000095      1.714286e-01  1.714285
# 108816   2.666666           0.000009   0.000095      9.192697e-06  0.000092
# 108817   5.000000           0.500000   5.000000      5.555564e-02  0.555556
# 108818   0.000003           0.750000   7.499995      2.544643e-01  2.544643
# 108819   4.999995           0.000009   0.000095      1.500001e-01  1.500001
#
#         boring_AHPweight     boring  depressing_AHPweight  depressing  \
# 0               0.500000   5.000000          0.000000e+00    0.000000
# 1               0.999999   9.999990          9.999980e-07    0.000010
# 2               0.500000   4.999997          0.000000e+00    0.000000
# 3               0.999999   9.999990          7.777774e-01    7.777774
# 4               0.000010   0.000096          7.500000e-01    7.500000
# ...                  ...        ...                   ...         ...
# 108815          0.500000   4.999997          1.000000e+00   10.000000
# 108816          1.000000  10.000000          2.500000e-01    2.500000
# 108817          0.749999   7.499990          5.000000e-01    5.000000
# 108818          0.750000   7.499999          9.690955e-06    0.000097
# 108819          0.500000   5.000000          3.000004e-01    3.000004
#
#                                     image_path
# 0       Hong Kong/50e5f7d4d7c3df413b00056a.JPG
# 1       Hong Kong/50e5f7d4d7c3df413b00056b.JPG
# 2       Hong Kong/50e5f7d4d7c3df413b00056c.JPG
# 3       Hong Kong/50e5f7d4d7c3df413b00056d.JPG
# 4       Hong Kong/50e5f7d4d7c3df413b00056e.JPG
# ...                                        ...
# 108815   Montreal/5185d533fdc9f03fd500148d.JPG
# 108816   Montreal/5185d533fdc9f03fd500148e.JPG
# 108817   Montreal/5185d534fdc9f03fd500148f.JPG
# 108818   Montreal/5185d534fdc9f03fd5001490.JPG
# 108819   Montreal/5185d536fdc9f03fd5001491.JPG
#
# [108438 rows x 19 columns]

# %%
summary_df.to_csv(f"{RESULTS_PATH}scores.csv", sep=";", index=False)

# %% [markdown]
# ### Statistics

# %% [markdown]
# #### Correlation matrix

# %%
# df = data_df[data_df["city"]=="Hong Kong"].copy()
# df = data_df[data_df["city"]=="Mexico City"].copy()
# df = data_df[data_df["city"]=="Gaborone"].copy()
# df = data_df[data_df["city"]=="Helsinki"].copy()

# %%
correlation_matrix = summary_df.loc[:, ["safety", "beautiful", "wealthy", "lively", "boring", "depressing"]].corr()
correlation_matrix
# Out:
#               safety  beautiful   wealthy    lively    boring  depressing
# safety      1.000000   0.030079  0.038679  0.014070 -0.010991   -0.026945
# beautiful   0.030079   1.000000  0.048168  0.017496 -0.019566   -0.046739
# wealthy     0.038679   0.048168  1.000000  0.024374 -0.023002   -0.045296
# lively      0.014070   0.017496  0.024374  1.000000 -0.016092   -0.016353
# boring     -0.010991  -0.019566 -0.023002 -0.016092  1.000000    0.027211
# depressing -0.026945  -0.046739 -0.045296 -0.016353  0.027211    1.000000

# %%
# confusion_matrix = pd.crosstab(data_df['annotations'], data_df['crimetype'], rownames=['annotations'], colnames=['crimetype'])

cmap=sns.diverging_palette(130, 700, s=100, as_cmap=True)
cmap="RdBu"

plt.figure(figsize=(20, 16))
sns_heatmap = sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap=cmap, center=0, vmin=-1, vmax=1, cbar=True, annot_kws={"size": 35})

# Customize the plot
sns_heatmap.set_title('Correlation Matrix', fontsize=0)
sns_heatmap.set_xlabel('Crime type', fontsize=0, rotation=0)
sns_heatmap.set_ylabel('Annotations', fontsize=0)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

# Display the plot
plt.show()

# %% [markdown]
# #### Aggregate information

# %%
aggregate_mean_df = pd.pivot_table(summary_df,
                      index=["city", "country", "continent"],
                      values=["image_id", "safety", "beautiful", "wealthy", "lively", "boring", "depressing"],
                      aggfunc = {
                          "image_id": len,
                          "safety": "mean",
                          "beautiful": "mean",
                          "wealthy": "mean",
                          "lively": "mean",
                          "boring": "mean",
                          "depressing": "mean",
                      }).rename(columns={"image_id": "num_images"}).reset_index().set_index(["city", "country", "continent", "num_images"])
aggregate_mean_df.columns = [ f"{c}_mean" for c in aggregate_mean_df.columns ]

aggregate_std_df = pd.pivot_table(summary_df,
                      index=["city", "country", "continent"],
                      values=["image_id", "safety", "beautiful", "wealthy", "lively", "boring", "depressing"],
                      aggfunc = {
                          "image_id": len,
                          "safety": "std",
                          "beautiful": "std",
                          "wealthy": "std",
                          "lively": "std",
                          "boring": "std",
                          "depressing": "std",
                      }).rename(columns={"image_id": "num_images"}).reset_index().set_index(["city", "country", "continent", "num_images"])
aggregate_std_df.columns = [ f"{c}_std" for c in aggregate_std_df.columns ]

aggregate_df = pd.merge(aggregate_mean_df, aggregate_std_df, on=["city", "country", "continent", "num_images"])
aggregate_df.reset_index(inplace=True)

new_columns = ["city", "country", "continent", "num_images"]
for metric in metrics:
    new_columns.append(f"{metric}_mean")
    new_columns.append(f"{metric}_std")

aggregate_df = aggregate_df[new_columns].copy()
aggregate_df.to_csv(f"{RESULTS_PATH}aggregate_statistics.csv", sep=";", index=False)

# %% [markdown]
# ##### Score histogram per category

# %%
for metric in metrics:
    verifyDir(f"{IMAGES_PATH}{metric}/")
    
    fig, ax = plt.subplots(figsize=(16,12), nrows=1, ncols=1, sharex=False, sharey=False)

    scores_df = pd.read_csv(f"{RESULTS_PATH}{metric}/weights.csv", sep=";", low_memory=False)
    scores = scores_df["AHPScore"].values

    sns_fig = sns.histplot(scores, 
                             bins=30, 
                             color='g', 
                             kde=False, 
                             label='City', 
                             ax=ax,
                             alpha=0.4)

    sns_fig.set_title(f"Histogram of {metric} scores", fontsize=30)
    sns_fig.set_ylabel('Num Images', fontsize=30)
    sns_fig.set_xlabel('Value', fontsize=30)

    # rotate the axis ticklabels
    _ = sns_fig.tick_params(axis='x', rotation=0, labelsize=20)

    # rotate the axis ticklabels
    _ = sns_fig.tick_params(axis='y', labelsize=30)

    # add annotation
    _ = sns_fig.bar_label(sns_fig.containers[0], fmt='%0.0f', fontsize=10,rotation=0)

    # add a space on y for the annotations
    #sns_fig.margins(x=0.1)
    ax.grid(True)

    # plt.xlim(-0.1, 10.1)
    # plt.xticks(np.arange(0.0, 10.1, 0.5))

    # ax.legend(fontsize=40)
    # a,b = ax.get_xlim()
    xticks = np.arange(0.0, 10.1, 0.5)  # Adjust the range and step as needed
    sns_fig.set_xticks(xticks)
    ax.set_xlim(-0.1, 10.1)

    # # Display the plot
    # plt.legend()

    fig.savefig(f'{IMAGES_PATH}/{metric}/score_distribution.png')
    plt.show()

# %% [markdown]
# ##### Score histogram per category and cities

# %%
for metric in metrics:
    verifyDir(f"{IMAGES_PATH}{metric}/cities/")
    verifyDir(f"{RESULTS_PATH}{metric}/cities/")
    
    scores_df = pd.read_csv(f"{RESULTS_PATH}{metric}/weights.csv", sep=";", low_memory=False)
    
    for current_city in scores_df["city"].unique().tolist():
        city_df = scores_df[scores_df["city"]==current_city].copy()
        city_df.to_csv(f"{RESULTS_PATH}/{metric}/cities/{current_city}.csv", sep=";", index=False)
        
        scores = city_df["AHPScore"].values
        
        fig, ax = plt.subplots(figsize=(16,12), nrows=1, ncols=1, sharex=False, sharey=False)
        
        sns_fig = sns.histplot(scores, 
                                 bins=30, 
                                 color='g', 
                                 kde=False, 
                                 label='City', 
                                 ax=ax,
                                 alpha=0.4)

        sns_fig.set_title(f"Histogram of {metric} scores in {current_city}", fontsize=30)
        sns_fig.set_ylabel('Num Images', fontsize=20)
        sns_fig.set_xlabel('Value', fontsize=20)

        # rotate the axis ticklabels
        _ = sns_fig.tick_params(axis='x', rotation=0, labelsize=20)

        # rotate the axis ticklabels
        _ = sns_fig.tick_params(axis='y', labelsize=20)

        # add annotation
        _ = sns_fig.bar_label(sns_fig.containers[0], fmt='%0.0f', fontsize=10,rotation=0)

        # add a space on y for the annotations
        #sns_fig.margins(x=0.1)
        ax.grid(True)

        # plt.xlim(-0.1, 10.1)
        # plt.xticks(np.arange(0.0, 10.1, 0.5))

        # ax.legend(fontsize=40)
        # a,b = ax.get_xlim()
        xticks = np.arange(0.0, 10.1, 0.5)  # Adjust the range and step as needed
        sns_fig.set_xticks(xticks)
        ax.set_xlim(-0.1, 10.1)

        # # Display the plot
        # plt.legend()

        fig.savefig(f'{IMAGES_PATH}/{metric}/cities/{current_city}_score_distribution.png')
        plt.close(fig)
#         plt.show()
